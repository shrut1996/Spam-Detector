# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url_train = pd.read_csv('dataset/url_train_features.csv', index_col=0)
url_train.head(10)
# Out:
#    host_count  avg_token_length  token_count  largest_token  url_length  \
# 0           8              8.00            3             18          52
# 1           8              8.00            3             18          43
# 2           3              4.33            3              7          42
# 3          28              5.67            3             11          33
# 4          28              5.67            3             11          33
# 5          83              6.00            2              9          23
# 6         197              6.33            3             11          57
# 7          53              4.67            3              8          27
# 8          83              6.00            2              9          23
# 9           1              5.33            3             10          43
#
#    ip_address  dots_count  critical_words  host_rank  host_country
# 0           0           2               0         -1            -1
# ...
